# %% [markdown]
# ###### Springboard Data Science Career Track Unit 4 Challenge - Tier 3 Complete
#
# ## Objectives
# Hey! Great job getting through those challenging DataCamp courses. You're learning a lot in a short span of time.
#
# In this notebook, you're going to apply the skills you've been learning, bridging the gap between the controlled environment of DataCamp and the *slightly* messier work that data scientists do with actual datasets!
#
# Here’s the mystery we’re going to solve: ***which boroughs of London have seen the greatest increase in housing prices, on average, over the last two decades?***
#
#
# A borough is just a fancy word for district. You may be familiar with the five boroughs of New York… well, there are 32 boroughs within Greater London [(here's some info for the curious)](https://en.wikipedia.org/wiki/London_boroughs). Some of them are more desirable areas to live in, and the data will reflect that with a greater rise in housing prices.
#
# ***This is the Tier 3 notebook, which means it's not filled in at all: we'll just give you the skeleton of a project, the brief and the data. It's up to you to play around with it and see what you can find out! Good luck! If you struggle, feel free to look at easier tiers for help; but try to dip in and out of them, as the more independent work you do, the better it is for your learning!***
#
# This challenge will make use of only what you learned in the following DataCamp courses:
# - Prework courses (Introduction to Python for Data Science, Intermediate Python for Data Science)
# - Data Types for Data Science
# - Python Data Science Toolbox (Part One)
# - pandas Foundations
# - Manipulating DataFrames with pandas
# - Merging DataFrames with pandas
#
# Of the tools, techniques and concepts in the above DataCamp courses, this challenge should require the application of the following:
# - **pandas**
#     - **data ingestion and inspection** (pandas Foundations, Module One)
#     - **exploratory data analysis** (pandas Foundations, Module Two)
#     - **tidying and cleaning** (Manipulating DataFrames with pandas, Module Three)
#     - **transforming DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **subsetting DataFrames with lists** (Manipulating DataFrames with pandas, Module One)
#     - **filtering DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **grouping data** (Manipulating DataFrames with pandas, Module Four)
#     - **melting data** (Manipulating DataFrames with pandas, Module Three)
#     - **advanced indexing** (Manipulating DataFrames with pandas, Module Four)
# - **matplotlib** (Intermediate Python for Data Science, Module One)
# - **fundamental data types** (Data Types for Data Science, Module One)
# - **dictionaries** (Intermediate Python for Data Science, Module Two)
# - **handling dates and times** (Data Types for Data Science, Module Four)
# - **function definition** (Python Data Science Toolbox - Part One, Module One)
# - **default arguments, variable length, and scope** (Python Data Science Toolbox - Part One, Module Two)
# - **lambda functions and error handling** (Python Data Science Toolbox - Part One, Module Four)

# %% [markdown]
# ## The Data Science Pipeline
#
# This is Tier Three, so we'll get you started. But after that, it's all in your hands! When you feel done with your investigations, look back over what you've accomplished, and prepare a quick presentation of your findings for the next mentor meeting.
#
# Data Science is magical. In this case study, you'll get to apply some complex machine learning algorithms. But as  [David Spiegelhalter](https://www.youtube.com/watch?v=oUs1uvsz0Ok) reminds us, there is no substitute for simply **taking a really, really good look at the data.** Sometimes, this is all we need to answer our question.
#
# Data Science projects generally adhere to the four stages of Data Science Pipeline:
# 1. Sourcing and loading
# 2. Cleaning, transforming, and visualizing
# 3. Modeling
# 4. Evaluating and concluding

# %% [markdown]
# ### 1. Sourcing and Loading
#
# Any Data Science project kicks off by importing  ***pandas***. The documentation of this wonderful library can be found [here](https://pandas.pydata.org/). As you've seen, pandas is conveniently connected to the [Numpy](http://www.numpy.org/) and [Matplotlib](https://matplotlib.org/) libraries.
#
# ***Hint:*** This part of the data science pipeline will test those skills you acquired in the pandas Foundations course, Module One.

# %% [markdown]
# #### 1.1. Importing Libraries

# %%
# Let's import the pandas, numpy libraries as pd, and np respectively. 
import pandas as pd
import numpy as np

# Load the pyplot collection of functions from matplotlib, as plt 
import matplotlib.pyplot as plt

# %% [markdown]
# #### 1.2.  Loading the data
# Your data comes from the [London Datastore](https://data.london.gov.uk/): a free, open-source data-sharing portal for London-oriented datasets.

# %%
# First, make a variable called url_LondonHousePrices, and assign it the following link, enclosed in quotation-marks as a string:
# https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls

url_LondonHousePrices = "https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls"

# The dataset we're interested in contains the Average prices of the houses, and is actually on a particular sheet of the Excel file. 
# As a result, we need to specify the sheet name in the read_excel() method.
# Put this data into a variable called properties.  
properties = pd.read_excel(url_LondonHousePrices, sheet_name='Average price', index_col= None)

# %% [markdown]
# ### 2. Cleaning, transforming, and visualizing
# This second stage is arguably the most important part of any Data Science project. The first thing to do is take a proper look at the data. Cleaning forms the majority of this stage, and can be done both before or after Transformation.
#
# The end goal of data cleaning is to have tidy data. When data is tidy:
#
# 1. Each variable has a column.
# 2. Each observation forms a row.
#
# Keep the end goal in mind as you move through this process, every step will take you closer.
#
#
#
# ***Hint:*** This part of the data science pipeline should test those skills you acquired in:
# - Intermediate Python for data science, all modules.
# - pandas Foundations, all modules.
# - Manipulating DataFrames with pandas, all modules.
# - Data Types for Data Science, Module Four.
# - Python Data Science Toolbox - Part One, all modules

# %% [markdown]
# **2.1. Exploring your data**
#
# Think about your pandas functions for checking out a dataframe.

# %%
properties.head()
# Out:
#   Unnamed: 0 City of London Barking & Dagenham       Barnet       Bexley  \
# 0        NaT      E09000001          E09000002    E09000003    E09000004
# 1 1995-01-01    91448.98487         50460.2266  93284.51832  64958.09036
# 2 1995-02-01    82202.77314        51085.77983  93190.16963  64787.92069
# 3 1995-03-01    79120.70256        51268.96956  92247.52435  64367.49344
# 4 1995-04-01    77101.20804        53133.50526  90762.87492  64277.66881
#
#          Brent      Bromley       Camden      Croydon       Ealing  ...  \
# 0    E09000005    E09000006    E09000007    E09000008    E09000009  ...
# 1  71306.56698  81671.47692  120932.8881  69158.16225  79885.89069  ...
# 2  72022.26197  81657.55944  119508.8622  68951.09542  80897.06551  ...
# 3  72015.76274  81449.31143  120282.2131  68712.44341  81379.86288  ...
# 4  72965.63094  81124.41227   120097.899  68610.04641  82188.90498  ...
#
#     NORTH WEST YORKS & THE HUMBER EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND  \
# ...

# %% [markdown]
# **2.2. Cleaning the data**
#
# You might find you need to transpose your dataframe, check out what its row indexes are, and reset the index. You  also might find you need to assign the values of the first row to your column headings  . (Hint: recall the .columns feature of DataFrames, as well as the iloc[] method).
#
# Don't be afraid to use StackOverflow for help  with this.

# %%
properties_t=properties.transpose()
type(properties_t)
# Out:
# pandas.core.frame.DataFrame

# %%
properties_t.head()
# Out:
#                           0                    1                    2    \
# Unnamed: 0                NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# City of London      E09000001          91448.98487          82202.77314
# Barking & Dagenham  E09000002           50460.2266          51085.77983
# Barnet              E09000003          93284.51832          93190.16963
# Bexley              E09000004          64958.09036          64787.92069
#
#                                     3                    4    \
# Unnamed: 0          1995-03-01 00:00:00  1995-04-01 00:00:00
# City of London              79120.70256          77101.20804
# Barking & Dagenham          51268.96956          53133.50526
# Barnet                      92247.52435          90762.87492
# Bexley                      64367.49344          64277.66881
#
#                                     5                    6    \
# Unnamed: 0          1995-05-01 00:00:00  1995-06-01 00:00:00
# ...

# %%
properties_t.columns
#checking out the column names. I want them to be the dates
# Out:
# RangeIndex(start=0, stop=333, step=1)

# %%
# The index should be integers rather than something we want to analyze. Checking the index
properties_t.index
# Out:
# Index(['Unnamed: 0', 'City of London', 'Barking & Dagenham', 'Barnet',
#        'Bexley', 'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey', 'Harrow',
#        'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth', 'Lewisham',
#        'Merton', 'Newham', 'Redbridge', 'Richmond upon Thames', 'Southwark',
#        'Sutton', 'Tower Hamlets', 'Waltham Forest', 'Wandsworth',
#        'Westminster', 'Unnamed: 34', 'Inner London', 'Outer London',
#        'Unnamed: 37', 'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER',
#        'EAST MIDLANDS', 'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON',
#        'SOUTH EAST', 'SOUTH WEST', 'Unnamed: 47', 'England'],
#       dtype='object')

# %%
# Resetting the index to integers
properties_t=properties_t.reset_index()

# %%
# Checking index for rows
properties_t.index
# Out:
# RangeIndex(start=0, stop=49, step=1)

# %% [markdown]
# **2.3. Cleaning the data (part 2)**
#
# You might we have to **rename** a couple columns. How do you do this? The clue's pretty bold...

# %%
properties_t.columns
# Out:
# Index(['index',       0,       1,       2,       3,       4,       5,       6,
#              7,       8,
#        ...
#            323,     324,     325,     326,     327,     328,     329,     330,
#            331,     332],
#       dtype='object', length=334)

# %%
#Reassigning column names to the 1st row which has index 0. Remember I just wnat the series and not the df, use []
properties_t.columns=properties_t.iloc[0]

# %%
properties_t.columns
# Out:
# Index([       'Unnamed: 0',                 NaT, 1995-01-01 00:00:00,
#        1995-02-01 00:00:00, 1995-03-01 00:00:00, 1995-04-01 00:00:00,
#        1995-05-01 00:00:00, 1995-06-01 00:00:00, 1995-07-01 00:00:00,
#        1995-08-01 00:00:00,
#        ...
#        2021-11-01 00:00:00, 2021-12-01 00:00:00, 2022-01-01 00:00:00,
#        2022-02-01 00:00:00, 2022-03-01 00:00:00, 2022-04-01 00:00:00,
#        2022-05-01 00:00:00, 2022-06-01 00:00:00, 2022-07-01 00:00:00,
#        2022-08-01 00:00:00],
#       dtype='object', name=0, length=334)

# %%
properties_t.head()
# Out:
# 0          Unnamed: 0        NaT  1995-01-01 00:00:00  1995-02-01 00:00:00  \
# 0          Unnamed: 0        NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# 1      City of London  E09000001          91448.98487          82202.77314
# 2  Barking & Dagenham  E09000002           50460.2266          51085.77983
# 3              Barnet  E09000003          93284.51832          93190.16963
# 4              Bexley  E09000004          64958.09036          64787.92069
#
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00  \
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00
# 1          79120.70256          77101.20804          84409.14932
# 2          51268.96956          53133.50526          53042.24852
# 3          92247.52435          90762.87492          90258.00033
# 4          64367.49344          64277.66881          63997.13588
#
# 0  1995-06-01 00:00:00  1995-07-01 00:00:00  1995-08-01 00:00:00  ...  \
# ...

# %%
# first row is now redundant
properties_t=properties_t.drop([0], axis=0)

# %%
properties_t.head()
# Out:
# 0          Unnamed: 0        NaT 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 1      City of London  E09000001         91448.98487         82202.77314
# 2  Barking & Dagenham  E09000002          50460.2266         51085.77983
# 3              Barnet  E09000003         93284.51832         93190.16963
# 4              Bexley  E09000004         64958.09036         64787.92069
# 5               Brent  E09000005         71306.56698         72022.26197
#
# 0 1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 1         79120.70256         77101.20804         84409.14932
# 2         51268.96956         53133.50526         53042.24852
# 3         92247.52435         90762.87492         90258.00033
# 4         64367.49344         64277.66881         63997.13588
# 5         72015.76274         72965.63094         73704.04743
#
# 0 1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  ...  \
# 1         94900.51244         110128.0423         112329.4376  ...
# ...

# %%
#Renaming columns 
properties_t = properties_t.rename(columns= {'Unnamed: 0':'London_Borough', pd.NaT: 'ID'})

# %%
properties_t.columns
# Out:
# Index([   'London_Borough',                'ID', 1995-01-01 00:00:00,
#        1995-02-01 00:00:00, 1995-03-01 00:00:00, 1995-04-01 00:00:00,
#        1995-05-01 00:00:00, 1995-06-01 00:00:00, 1995-07-01 00:00:00,
#        1995-08-01 00:00:00,
#        ...
#        2021-11-01 00:00:00, 2021-12-01 00:00:00, 2022-01-01 00:00:00,
#        2022-02-01 00:00:00, 2022-03-01 00:00:00, 2022-04-01 00:00:00,
#        2022-05-01 00:00:00, 2022-06-01 00:00:00, 2022-07-01 00:00:00,
#        2022-08-01 00:00:00],
#       dtype='object', name=0, length=334)

# %%
properties_t.head()
# Out:
# 0      London_Borough         ID 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 1      City of London  E09000001         91448.98487         82202.77314
# 2  Barking & Dagenham  E09000002          50460.2266         51085.77983
# 3              Barnet  E09000003         93284.51832         93190.16963
# 4              Bexley  E09000004         64958.09036         64787.92069
# 5               Brent  E09000005         71306.56698         72022.26197
#
# 0 1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 1         79120.70256         77101.20804         84409.14932
# 2         51268.96956         53133.50526         53042.24852
# 3         92247.52435         90762.87492         90258.00033
# 4         64367.49344         64277.66881         63997.13588
# 5         72015.76274         72965.63094         73704.04743
#
# 0 1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  ...  \
# 1         94900.51244         110128.0423         112329.4376  ...
# ...

# %% [markdown]
# **2.4.Transforming the data**
#
# Remember what Wes McKinney said about tidy data?
#
# You might need to **melt** your DataFrame here.

# %%
properties_melt=properties_t.melt(id_vars=["London_Borough",'ID'])

# %%
properties_melt.head(50)
# Out:
#           London_Borough         ID          0        value
# 0         City of London  E09000001 1995-01-01  91448.98487
# 1     Barking & Dagenham  E09000002 1995-01-01   50460.2266
# 2                 Barnet  E09000003 1995-01-01  93284.51832
# 3                 Bexley  E09000004 1995-01-01  64958.09036
# 4                  Brent  E09000005 1995-01-01  71306.56698
# 5                Bromley  E09000006 1995-01-01  81671.47692
# 6                 Camden  E09000007 1995-01-01  120932.8881
# 7                Croydon  E09000008 1995-01-01  69158.16225
# 8                 Ealing  E09000009 1995-01-01  79885.89069
# 9                Enfield  E09000010 1995-01-01  72514.69096
# 10             Greenwich  E09000011 1995-01-01  62300.10169
# 11               Hackney  E09000012 1995-01-01  61296.52637
# 12  Hammersmith & Fulham  E09000013 1995-01-01  124902.8602
# 13              Haringey  E09000014 1995-01-01  76287.56947
# 14                Harrow  E09000015 1995-01-01  84769.52599
# ...

# %%
properties_melt.rename(columns={0:'Month', 'value':'Avg_price'},inplace=True)

# %%
properties_melt.columns
# Out:
# Index(['London_Borough', 'ID', 'Month', 'Avg_price'], dtype='object')

# %% [markdown]
# Remember to make sure your column data types are all correct. Average prices, for example, should be floating point numbers...

# %%
#Checking the variable types are correct
properties_melt.dtypes
# Out:
# London_Borough            object
# ID                        object
# Month             datetime64[ns]
# Avg_price                 object
# dtype: object

# %%
#Changing the avergae price to a float
properties_melt['Avg_price']=pd.to_numeric(properties_melt['Avg_price'])

# %%
properties_melt.dtypes
# Out:
# London_Borough            object
# ID                        object
# Month             datetime64[ns]
# Avg_price                float64
# dtype: object

# %% [markdown]
# **2.5. Cleaning the data (part 3)**
#
# Do we have an equal number of observations in the ID, Average Price, Month, and London Borough columns? Remember that there are only 32 London Boroughs. How many entries do you have in that column?
#
# Check out the contents of the London Borough column, and if you find null values, get rid of them however you see fit.

# %%
#Counting the missing data
properties_melt.isna().sum()
# Out:
# London_Borough      0
# ID                996
# Month               0
# Avg_price         996
# dtype: int64

# %%
properties_melt.head(50)
# Out:
#           London_Borough         ID      Month     Avg_price
# 0         City of London  E09000001 1995-01-01   91448.98487
# 1     Barking & Dagenham  E09000002 1995-01-01   50460.22660
# 2                 Barnet  E09000003 1995-01-01   93284.51832
# 3                 Bexley  E09000004 1995-01-01   64958.09036
# 4                  Brent  E09000005 1995-01-01   71306.56698
# 5                Bromley  E09000006 1995-01-01   81671.47692
# 6                 Camden  E09000007 1995-01-01  120932.88810
# 7                Croydon  E09000008 1995-01-01   69158.16225
# 8                 Ealing  E09000009 1995-01-01   79885.89069
# 9                Enfield  E09000010 1995-01-01   72514.69096
# 10             Greenwich  E09000011 1995-01-01   62300.10169
# 11               Hackney  E09000012 1995-01-01   61296.52637
# 12  Hammersmith & Fulham  E09000013 1995-01-01  124902.86020
# 13              Haringey  E09000014 1995-01-01   76287.56947
# ...

# %%
#Subsetting or filtering for missing data and storing it in a df called missing
missing=properties_melt[properties_melt['ID'].isna()]

# %%
missing
# Out:
#       London_Borough   ID      Month  Avg_price
# 33       Unnamed: 34  NaN 1995-01-01        NaN
# 36       Unnamed: 37  NaN 1995-01-01        NaN
# 46       Unnamed: 47  NaN 1995-01-01        NaN
# 81       Unnamed: 34  NaN 1995-02-01        NaN
# 84       Unnamed: 37  NaN 1995-02-01        NaN
# ...              ...  ...        ...        ...
# 15876    Unnamed: 37  NaN 2022-07-01        NaN
# 15886    Unnamed: 47  NaN 2022-07-01        NaN
# 15921    Unnamed: 34  NaN 2022-08-01        NaN
# 15924    Unnamed: 37  NaN 2022-08-01        NaN
# 15934    Unnamed: 47  NaN 2022-08-01        NaN
#
# [996 rows x 4 columns]

# %%
# Keeping everything BUT the missing data: 14940+996=15936
properties_c=properties_melt.dropna()

# %%
#Checking that we dropped the missing values
properties_c.count()
# Out:
# London_Borough    14940
# ID                14940
# Month             14940
# Avg_price         14940
# dtype: int64

# %%
# A list of non-boroughs. 
nonBoroughs = ['Inner London', 'Outer London', 
               'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER', 
               'EAST MIDLANDS', 'WEST MIDLANDS',
              'EAST OF ENGLAND', 'LONDON', 'SOUTH EAST', 
              'SOUTH WEST', 'England']

# %%
# Checking how many rows are in the non-boroughs list. We need to eliminate these.
properties_c[properties_c.London_Borough.isin(nonBoroughs)]
# Out:
#            London_Borough         ID      Month     Avg_price
# 34           Inner London  E13000001 1995-01-01   78251.97650
# 35           Outer London  E13000002 1995-01-01   72958.79836
# 37             NORTH EAST  E12000001 1995-01-01   42076.35411
# 38             NORTH WEST  E12000002 1995-01-01   43958.48001
# 39     YORKS & THE HUMBER  E12000003 1995-01-01   44803.42878
# ...                   ...        ...        ...           ...
# 15930     EAST OF ENGLAND  E12000006 2022-08-01  364885.04444
# 15931              LONDON  E12000007 2022-08-01  552755.27026
# 15932          SOUTH EAST  E12000008 2022-08-01  406980.66404
# 15933          SOUTH WEST  E12000009 2022-08-01  335927.47192
# 15935             England  E92000001 2022-08-01  315964.75986
#
# [3984 rows x 4 columns]

# %%
properties_c=properties_c[~properties_c.London_Borough.isin(nonBoroughs)]

# %%
properties_c.head()
# Out:
#        London_Borough         ID      Month    Avg_price
# 0      City of London  E09000001 1995-01-01  91448.98487
# 1  Barking & Dagenham  E09000002 1995-01-01  50460.22660
# 2              Barnet  E09000003 1995-01-01  93284.51832
# 3              Bexley  E09000004 1995-01-01  64958.09036
# 4               Brent  E09000005 1995-01-01  71306.56698

# %%
# Question: Why do we have to copy the data frame?
df=properties_c

# %%
# Eliminating the rows that are in the non-boroughs list.(Doing it this way created an error later see notes)
#df=properties_c[~properties_c.London_Borough.isin(nonBoroughs)]

# %%
df.head()
# Out:
#        London_Borough         ID      Month    Avg_price
# 0      City of London  E09000001 1995-01-01  91448.98487
# 1  Barking & Dagenham  E09000002 1995-01-01  50460.22660
# 2              Barnet  E09000003 1995-01-01  93284.51832
# 3              Bexley  E09000004 1995-01-01  64958.09036
# 4               Brent  E09000005 1995-01-01  71306.56698

# %%
#1490-3984=10956
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10956 entries, 0 to 15920
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   London_Borough  10956 non-null  object
#  1   ID              10956 non-null  object
#  2   Month           10956 non-null  datetime64[ns]
#  3   Avg_price       10956 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(2)
# memory usage: 428.0+ KB

# %%
df.columns
# Out:
# Index(['London_Borough', 'ID', 'Month', 'Avg_price'], dtype='object')

# %% [markdown]
# **2.6. Visualizing the data**
#
# To visualize the data, why not subset on a particular London Borough? Maybe do a line plot of Month against Average Price?

# %%
Barnet=df[df['London_Borough']=='Barnet']

# %%
Barnet.head()
# Out:
#     London_Borough         ID      Month    Avg_price
# 2           Barnet  E09000003 1995-01-01  93284.51832
# 50          Barnet  E09000003 1995-02-01  93190.16963
# 98          Barnet  E09000003 1995-03-01  92247.52435
# 146         Barnet  E09000003 1995-04-01  90762.87492
# 194         Barnet  E09000003 1995-05-01  90258.00033

# %%
Barnet.plot(x='Month',y='Avg_price', kind='line')
# Out:
# <AxesSubplot:xlabel='Month'>

# %% [markdown]
# To limit the number of data points you have, you might want to extract the year from every month value your *Month* column.
#
# To this end, you *could* apply a ***lambda function***. Your logic could work as follows:
# 1. look through the `Month` column
# 2. extract the year from each individual value in that column
# 3. store that corresponding year as separate column.
#
# Whether you go ahead with this is up to you. Just so long as you answer our initial brief: which boroughs of London have seen the greatest house price increase, on average, over the past two decades?

# %%
#Creating column with the year using a lamda function
df['Year']=df['Month'].apply(lambda t:t.year)

# %%
df.head()
# Out:
#        London_Borough         ID      Month    Avg_price  Year
# 0      City of London  E09000001 1995-01-01  91448.98487  1995
# 1  Barking & Dagenham  E09000002 1995-01-01  50460.22660  1995
# 2              Barnet  E09000003 1995-01-01  93284.51832  1995
# 3              Bexley  E09000004 1995-01-01  64958.09036  1995
# 4               Brent  E09000005 1995-01-01  71306.56698  1995

# %%
# Averaging per year for ea borough
df_yearly=df.groupby(['London_Borough','Year']) ['Avg_price'].mean()

# %%
df_yearly.sample(10)
# Out:
# London_Borough        Year
# Kensington & Chelsea  2020    1.326363e+06
# Barking & Dagenham    2003    1.424989e+05
# Havering              2011    2.195588e+05
# Ealing                1997    9.780582e+04
# Barnet                2020    5.257802e+05
# Sutton                2000    1.259520e+05
# Kensington & Chelsea  1997    2.466556e+05
# Lambeth               1995    6.810569e+04
# Sutton                2007    2.414380e+05
#                       2018    3.792626e+05
# Name: Avg_price, dtype: float64

# %%
#Notice that df_yearly is now a pandas series rather than a data frame
df_yearly.info()
# Out:
# <class 'pandas.core.series.Series'>
# MultiIndex: 924 entries, ('Barking & Dagenham', 1995) to ('Westminster', 2022)
# Series name: Avg_price
# Non-Null Count  Dtype
# --------------  -----
# 924 non-null    float64
# dtypes: float64(1)
# memory usage: 10.7+ KB

# %%
#Interesting that when we reset the index of a pandas series it's converted to a data frame (see info below)
df_yearly=df_yearly.reset_index()

# %%
df_yearly.head(30)
# Out:
#         London_Borough  Year      Avg_price
# 0   Barking & Dagenham  1995   51817.969390
# 1   Barking & Dagenham  1996   51718.192690
# 2   Barking & Dagenham  1997   55974.262309
# 3   Barking & Dagenham  1998   60285.821083
# 4   Barking & Dagenham  1999   65320.934441
# 5   Barking & Dagenham  2000   77549.513290
# 6   Barking & Dagenham  2001   88664.058223
# 7   Barking & Dagenham  2002  112221.912482
# 8   Barking & Dagenham  2003  142498.927800
# 9   Barking & Dagenham  2004  158175.982483
# 10  Barking & Dagenham  2005  163360.782017
# 11  Barking & Dagenham  2006  167853.342558
# 12  Barking & Dagenham  2007  184909.807383
# 13  Barking & Dagenham  2008  187356.865783
# 14  Barking & Dagenham  2009  156446.896358
# 15  Barking & Dagenham  2010  166560.705275
# 16  Barking & Dagenham  2011  163465.144225
# 17  Barking & Dagenham  2012  165863.911600
# 18  Barking & Dagenham  2013  173733.624933
# 19  Barking & Dagenham  2014  201172.229417
# ...

# %%
# So now it's a data frame!
df_yearly.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 924 entries, 0 to 923
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   London_Borough  924 non-null    object
#  1   Year            924 non-null    int64
#  2   Avg_price       924 non-null    float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 21.8+ KB

# %%
#Attempting to do a line graph for each borough using a pivot table
df_yearly_pivot=df_yearly.pivot_table(values='Avg_price',index='Year', columns='London_Borough')
#df_yearly_pivot=df_yearly_pivot.set_index('Year')
df_yearly_pivot
# Out:
# London_Borough  Barking & Dagenham         Barnet         Bexley  \
# Year
# 1995                  51817.969390   91792.537433   64291.532845
# 1996                  51718.192690   94000.445448   65490.417234
# 1997                  55974.262309  106883.185546   70789.406602
# 1998                  60285.821083  122359.468033   80632.020822
# 1999                  65320.934441  136004.512067   86777.715903
# 2000                  77549.513290  167952.633958  103186.665184
# 2001                  88664.058223  185563.352600  116527.134750
# 2002                 112221.912482  220746.059225  136797.964475
# 2003                 142498.927800  251212.927683  164482.038908
# 2004                 158175.982483  271854.112992  179141.168258
# 2005                 163360.782017  279459.669683  186512.186267
# 2006                 167853.342558  291337.796208  191831.056892
# 2007                 184909.807383  326915.498517  208085.873442
# ...

# %%
#Attempting to graph all boroughs in the same line graph
Boroughs=df_yearly_pivot.columns
Boroughs
# Out:
# Index(['Barking & Dagenham', 'Barnet', 'Bexley', 'Brent', 'Bromley', 'Camden',
#        'City of London', 'Croydon', 'Ealing', 'Enfield', 'Greenwich',
#        'Hackney', 'Hammersmith & Fulham', 'Haringey', 'Harrow', 'Havering',
#        'Hillingdon', 'Hounslow', 'Islington', 'Kensington & Chelsea',
#        'Kingston upon Thames', 'Lambeth', 'Lewisham', 'Merton', 'Newham',
#        'Redbridge', 'Richmond upon Thames', 'Southwark', 'Sutton',
#        'Tower Hamlets', 'Waltham Forest', 'Wandsworth', 'Westminster'],
#       dtype='object', name='London_Borough')

# %%
#Is there a way to show the names of the boroughs? See line 6 
#Not the best graph though hard to see and colors seem to repeat?
plt.xlabel('Year')
plt.ylabel('Average Price')
plt.title('London Boroughs')
plt.plot(df_yearly_pivot[Boroughs]) # got this code from plotting a time series
plt.legend(['Barking & Dagenham', 'Barnet', 'Bexley', 'Brent', 'Bromley', 'Camden',
       'City of London', 'Croydon', 'Ealing', 'Enfield', 'Greenwich',
       'Hackney', 'Hammersmith & Fulham', 'Haringey', 'Harrow', 'Havering',
       'Hillingdon', 'Hounslow', 'Islington', 'Kensington & Chelsea',
       'Kingston upon Thames', 'Lambeth', 'Lewisham', 'Merton', 'Newham',
       'Redbridge', 'Richmond upon Thames', 'Southwark', 'Sutton',
       'Tower Hamlets', 'Waltham Forest', 'Wandsworth', 'Westminster'])

# %%
#Oh my! this is less code for the same result!
ax=df_yearly_pivot.plot()
# Formatting the graph
plt.xlabel('Year')
plt.ylabel('Average Price')
plt.title('London Boroughs')
# Out:
# Text(0.5, 1.0, 'London Boroughs')

# %% [markdown]
# **3. Modeling**
#
# Consider creating a function that will calculate a ratio of house prices, comparing the price of a house in 2018 to the price in 1998.
#
# Consider calling this function create_price_ratio.
#
# You'd want this function to:
# 1. Take a filter of dfg, specifically where this filter constrains the London_Borough, as an argument. For example, one admissible argument should be: dfg[dfg['London_Borough']=='Camden'].
# 2. Get the Average Price for that Borough, for the years 1998 and 2018.
# 4. Calculate the ratio of the Average Price for 1998 divided by the Average Price for 2018.
# 5. Return that ratio.
#
# Once you've written this function, you ultimately want to use it to iterate through all the unique London_Boroughs and work out the ratio capturing the difference of house prices between 1998 and 2018.
#
# Bear in mind: you don't have to write a function like this if you don't want to. If you can solve the brief otherwise, then great!
#
# ***Hint***: This section should test the skills you acquired in:
# - Python Data Science Toolbox - Part One, all modules

# %%
#Function to calculate ratio. Remember that to create a dataframe later we need a dictionary of lists!
def compare (d):
    y1998=float(d['Avg_price'][d['Year']==1998])
    y2018=float(d['Avg_price'][d['Year']==2018])    
    ratio= [y1998/y2018]
    return ratio

# %%
compare(df_yearly[df_yearly["London_Borough"]=='Camden'])
# Out:
# [0.20261973503252542]

# %%
# Creating a dictionay called final with the borough as the key and the value is the ratio
final={}
for b in df_yearly['London_Borough'].unique():
    borough=df_yearly[df_yearly['London_Borough']==b]
    final[b]=compare(borough) #b is the key with value=ratio
print(final)
# Out:
# {'Barking & Dagenham': [0.20422256235393685], 'Barnet': [0.229452741207858], 'Bexley': [0.2353507654063011], 'Brent': [0.2043086864360114], 'Bromley': [0.24421308489837315], 'Camden': [0.20261973503252542], 'City of London': [0.18862157770244364], 'Croydon': [0.23803288028014052], 'Ealing': [0.23194048191708755], 'Enfield': [0.23455064269011858], 'Greenwich': [0.20995010893854213], 'Hackney': [0.16133493530705728], 'Hammersmith & Fulham': [0.24167443054605847], 'Haringey': [0.19475619095546956], 'Harrow': [0.24635417785626296], 'Havering': [0.2312015578701476], 'Hillingdon': [0.23807975835429931], 'Hounslow': [0.25148317824115635], 'Islington': [0.20643891170300288], 'Kensington & Chelsea': [0.19675491852791563], 'Kingston upon Thames': [0.2341619023428255], 'Lambeth': [0.20170435486140825], 'Lewisham': [0.18351246764721704], 'Merton': [0.21091380604361798], 'Newham': [0.18848754146121072], 'Redbridge': [0.2236545053715767], 'Richmond upon Thames': [0.24967779731157863], 'Southwark':
# ...

# %%
df_ratios=pd.DataFrame(final)

# %%
df_ratios
# Out:
#    Barking & Dagenham    Barnet    Bexley     Brent   Bromley   Camden  \
# 0            0.204223  0.229453  0.235351  0.204309  0.244213  0.20262
#
#    City of London   Croydon   Ealing   Enfield  ...    Merton    Newham  \
# 0        0.188622  0.238033  0.23194  0.234551  ...  0.210914  0.188488
#
#    Redbridge  Richmond upon Thames  Southwark    Sutton  Tower Hamlets  \
# 0   0.223655              0.249678   0.181275  0.242806       0.216137
#
#    Waltham Forest  Wandsworth  Westminster
# 0        0.171387    0.210185     0.186791
#
# [1 rows x 33 columns]

# %%
df_ratios_t=df_ratios.transpose()
df_ratios=df_ratios_t.reset_index() #Why do we need to rename the data frame?
df_ratios.head()
# Out:
#                 index         0
# 0  Barking & Dagenham  0.204223
# 1              Barnet  0.229453
# 2              Bexley  0.235351
# 3               Brent  0.204309
# 4             Bromley  0.244213

# %%
df_ratios.rename(columns={'index':'London_Borough',0:'ratio 2018'}, inplace=True) #Why do we need the inplace here?

# %%
df_ratios.columns
# Out:
# Index(['London_Borough', 'ratio 2018'], dtype='object')

# %%
df_ratios_sorted=df_ratios.sort_values('ratio 2018', ascending=True)
df_ratios_sorted
# Out:
#           London_Borough  ratio 2018
# 11               Hackney    0.161335
# 30        Waltham Forest    0.171387
# 27             Southwark    0.181275
# 22              Lewisham    0.183512
# 32           Westminster    0.186791
# 24                Newham    0.188488
# 6         City of London    0.188622
# 13              Haringey    0.194756
# 19  Kensington & Chelsea    0.196755
# 21               Lambeth    0.201704
# 5                 Camden    0.202620
# 0     Barking & Dagenham    0.204223
# 3                  Brent    0.204309
# 18             Islington    0.206439
# 10             Greenwich    0.209950
# 31            Wandsworth    0.210185
# 23                Merton    0.210914
# 29         Tower Hamlets    0.216137
# 25             Redbridge    0.223655
# 1                 Barnet    0.229453
# 15              Havering    0.231202
# 8                 Ealing    0.231940
# 20  Kingston upon Thames    0.234162
# 9                Enfield    0.234551
# ...

# %%
top15=df_ratios.sort_values('ratio 2018',ascending=True).head(15)

# %%
bar_graph=top15[['London_Borough','ratio 2018']].plot(kind='bar',rot=90)
bar_graph.set_xticklabels(top15.London_Borough)
# Out:
# [Text(0, 0, 'Hackney'),
#  Text(1, 0, 'Waltham Forest'),
#  Text(2, 0, 'Southwark'),
#  Text(3, 0, 'Lewisham'),
#  Text(4, 0, 'Westminster'),
#  Text(5, 0, 'Newham'),
#  Text(6, 0, 'City of London'),
#  Text(7, 0, 'Haringey'),
#  Text(8, 0, 'Kensington & Chelsea'),
#  Text(9, 0, 'Lambeth'),
#  Text(10, 0, 'Camden'),
#  Text(11, 0, 'Barking & Dagenham'),
#  Text(12, 0, 'Brent'),
#  Text(13, 0, 'Islington'),
#  Text(14, 0, 'Greenwich')]

# %%
top_5_list=top15['London_Borough'].head(5)
top5_data=df_yearly[df_yearly.London_Borough.isin(top_5_list)]
top5_data
# Out:
#     London_Borough  Year     Avg_price
# 308        Hackney  1995  6.602448e+04
# 309        Hackney  1996  6.924765e+04
# 310        Hackney  1997  7.817680e+04
# 311        Hackney  1998  8.786954e+04
# 312        Hackney  1999  1.055330e+05
# ..             ...   ...           ...
# 919    Westminster  2018  1.020025e+06
# 920    Westminster  2019  9.559986e+05
# 921    Westminster  2020  9.604692e+05
# 922    Westminster  2021  9.627774e+05
# 923    Westminster  2022  1.010634e+06
#
# [140 rows x 3 columns]

# %%
#pivot table of top5
top5_pivot=top5_data.pivot_table(values='Avg_price',index='Year', columns='London_Borough')

# %%
#Oh my! this is less code for the same result!!!
ax1=top5_pivot.plot()
# Formatting the graph
       
plt.xlabel('Year')
plt.ylabel('Average Price')
plt.title('Top 5 Boroughs')
# Out:
# Text(0.5, 1.0, 'Top 5 Boroughs')

# %%
df_ratios['ratio 2018'].mean()
# Out:
# 0.21491012557265776

# %%
df_ratios['ratio 2018'].std()
# Out:
# 0.024662084704145635

# %%
df_ratios['ratio 2018'].median()
# Out:
# 0.21091380604361798

# %%
df_ratios['ratio 2018'].quantile(.25)
# Out:
# 0.19675491852791563

# %% [markdown]
# ### 4. Conclusion
# What can you conclude? Type out your conclusion below.
#
# Look back at your notebook. Think about how you might summarize what you have done, and prepare a quick presentation on it to your mentor at your next meeting.
#
# We hope you enjoyed this practical project. It should have consolidated your data hygiene and pandas skills by looking at a real-world problem involving just the kind of dataset you might encounter as a budding data scientist. Congratulations, and looking forward to seeing you at the next step in the course!

# %% [markdown]
# Per the bar graph we can see that the borough with the most increase in the average price over the last 2 decades is Hackney followed by Waltham Forest and Southwark. However, after that the difference is in the thousands of a percent, meaning that the next boroughs had a similar increase.
